# %%
import numpy as np
import random
from random import shuffle
import os
import gensim
import re
import pickle
import tensorflow as tf
import operator
import math
import sys
from copy import deepcopy
from collections import Counter
import string
import fileinput
from nltk.tokenize import sent_tokenize, word_tokenize 
import nltk

from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql.functions import split, explode
from pyspark.sql import functions as func
from pyspark.sql.types import *
from pyspark.ml.linalg import Vectors, DenseVector, VectorUDT

from tensorflow.python.ops import rnn, rnn_cell
from tensorflow.python.framework import ops
from tensorflow.models.rnn.translate import seq2seq_model

# %%
data_dir = '/media/ai2-rey/data_disk/data_sets/'

# %%
with open(data_dir+'abstracts.txt', 'r') as f:
    abstracts = [line.strip() for line in f]
    abstracts = abstracts[:1000000]

# %%
with open(data_dir+'titles.txt','r') as f:
    titles = [line.strip() for line in f]
    titles = titles[:1000000]

# %%
l = len(abstracts)
train_abstracts = abstracts[:int(0.9*l)]
train_titles = titles[:int(0.9*l)]

test_abstracts = abstracts[int(0.9*l):]
test_titles = titles[int(0.9*l):]

# %%
del abstracts
del titles

# %%
UNKNOWN = "*UNKNOWN*"
PAD = "*PAD*"

def generate_embedding_files(filename):
    embeddings = {}
    for line in open(filename):
        parts = line.split()
        embeddings[parts[0]] = list(map(float, parts[1:]))
    embedding_size = len(list(embeddings.values())[0])
    embeddings[UNKNOWN] = [0.0 for _ in range(embedding_size)]
    embeddings[PAD] = [1.0 for _ in range(embedding_size)]
    
    words = embeddings.keys()
    embedding_matrix = np.array([embeddings[word] for word in list(embeddings.keys())])
    return words, embedding_matrix

glove_words, glove_embedding_matrix = generate_embedding_files('/media/ai2-rey/data_disk/data_sets/glove.6B/glove.6B.50d.txt')
glove_vocab_lookup = {word: i for i, word  in enumerate(glove_words)}
glove_vocab_size, glove_embedding_size= glove_embedding_matrix.shape

# %%
class TextSum_Dataset:
  
    def __init__(self, abstract, title, word2id_dict=None, 
                 id2word_dict=None, use_glove = True, 
                 max_vocab_size=None, autopad_abstract='max', 
                 autopad_title ='max', abstract_pad_len=None, title_pad_len = None):

        assert autopad_abstract in {'min', 'max', 'avg'}
        assert autopad_title in {'min', 'max', 'avg'}
     
        self.abstract = abstract
        self.title = title
        
        self.max_vocab_size = max_vocab_size
        
        self.abstract_pad_len = abstract_pad_len
        self.title_pad_len = title_pad_len
        self.__autopad_abstract = autopad_abstract
        self.__autopad_title = autopad_title
        
        self.vocab = set()
        self.word_counter = dict()
        self.use_glove = use_glove
        self.word2id_dict = word2id_dict
        self.id2word_dict = id2word_dict
        
        self.abstract_ids = None
        self.title_ids = None
        self.abstract_lens = None
        self.titles_lens = None
        
        self.__parse_data()
        if self.word2id_dict is None: self.__create_word2id_dict() 
        self.__numericize_data()

    def __normalize_text(self, s):
        def remove_articles(text):
            return re.sub(r'\b(a|an|the)\b', ' ', text)

        def white_space_fix(text):
            return ' '.join(text.split())

        def remove_punc(text):
            exclude = set(string.punctuation)
            exclude.discard('.')
            return ''.join(ch for ch in text if ch not in exclude)

        def lower(text):
            return text.lower()

        def add_space(text):
            return text.replace('.', ' . ')

        return white_space_fix(add_space(remove_punc(lower(s))))

    
    def __update_word_counter(self, sequence):
        """ Update word_counter with counts for words in a sentence
        
        Args:
            sequence (list<str>) : list of words in a sequence
        
        """
        for word in sequence:
            self.word_counter[word] = self.word_counter.get(word, 0) + 1
            
    def __create_vocab(self):
        """ Create set of most frequent unique words found in the training data """
        
        if self.max_vocab_size == None:
            self.vocab = set(self.word_counter.keys())
        else:
            self.vocab = set(sorted(self.word_counter, key=self.word_counter.get, reverse=True)[:self.max_vocab_size])
        
    def __shuffle_data(self, data):
        random.shuffle(data)
        return list(zip(*data))
    
    def __parse_data(self):
        
        abstracts = []
        titles = []
        
        for idx in range(len(self.abstract)):
            a = self.__normalize_text(self.abstract[idx])
            t = self.__normalize_text(self.title[idx])
            
            self.__update_word_counter(a.split())
            self.__update_word_counter(t.split())
            
            abstracts.append(a)
            titles.append(t)
            
        self.abstract = abstracts
        self.title = titles
        
        del abstracts
        del titles
        
        self.__create_vocab()
        
        shuffle = list(zip(self.abstract, self.title))        
        self.abstract, self.title = self.__shuffle_data(shuffle)
    
    def __create_word2id_dict(self):
        
        if self.word2id_dict == None:
            self.word2id_dict = dict()
            self.id2word_dict = dict()
            misc_tokens = ['PAD', 'UNK']

            for i, token in enumerate(misc_tokens):
                self.word2id_dict[token] = i

            for word in self.vocab:
                self.word2id_dict[word] = len(self.word2id_dict)

            self.vocab |= set(misc_tokens)
            
            word2id = glove_vocab_lookup if self.use_glove else self.word2id_dict
            self.id2word_dict = dict(zip(word2id.values(), word2id.keys()))
            
            self.num_tokens = len(self.word2id_dict)
    
    def __convert_word2id(self, word):
        
        try:
            word_id = glove_vocab_lookup[word] if self.use_glove else self.word2id_dict[word]
        except:
            word_id = glove_vocab_lookup[UNKNOWN] if self.use_glove else self.word2id_dict['UNK']

        return word_id
    
    def __apply_padding(self, s, pad_len):
        sequence = s[:]
        
        PAD_sym = glove_vocab_lookup[PAD] if self.use_glove else self.word2id_dict['PAD'] 
        
        if len(sequence) < pad_len:
            sequence += [PAD_sym for i in range(pad_len - len(sequence))]
        elif len(sequence) > pad_len:
            sequence = sequence[:pad_len]
        else:
            pass
        return sequence
        
    def __get_seq_length_stats(self, sequences):
        max_len = 0
        min_len = 100000
        avg_len = 0
        for sequence in sequences:
            max_len = max(max_len, len(sequence))
            min_len = min(min_len, len(sequence))
            avg_len += len(sequence)
        avg_len = int(float(avg_len) / len(sequences))
        return min_len, max_len, avg_len

    def __get_max_sequence_lengths(self, abstract_ids, title_ids):
        min_abstract_len, max_abstract_len, avg_abstract_len = self.__get_seq_length_stats(abstract_ids)
        min_title_len, max_title_len, avg_title_len = self.__get_seq_length_stats(title_ids)

        if self.abstract_pad_len == None:
            if self.__autopad_abstract != None:
                if self.__autopad_abstract == 'min':
                    self.abstract_pad_len = min_abstract_len
                elif self.__autopad_abstract == 'max':
                    self.abstract_pad_len = max_abstract_len
                elif self.__autopad_abstract == 'avg':
                    self.abstract_pad_len = avg_abstract_len
            else:
                self.abstract_pad_len = avg_abstract_len
                
        if self.title_pad_len == None:
            if self.__autopad_title != None:
                if self.__autopad_title == 'min':
                    self.title_pad_len = min_title_len
                elif self.__autopad_title == 'max':
                    self.title_pad_len = max_title_len
                elif self.__autopad_title == 'avg':
                    self.title_pad_len = avg_title_len
            else:
                self.title_pad_len = avg_title_len     
    
    def __tokenize_sentences(self, abstract_ids, title_ids):
        """ Tokenizes sentences.
        :param raw: dict returned from load_babi
        :param word_table: WordTable
        :return:
        """
        abstract_tokens = []
        title_tokens = []
        
        for i in range(len(abstract_ids)):
            a_tkn_ids = self.__apply_padding(abstract_ids[i], self.abstract_pad_len)
            abstract_tokens.append(a_tkn_ids)
            t_tkn_ids = self.__apply_padding(title_ids[i], self.title_pad_len)
            title_tokens.append(t_tkn_ids)
            
        return abstract_tokens, title_tokens
        
    def __convert_text2ids(self, abstract, title):
        """ Tokenizes sentences.
        :param raw: dict returned from load_babi
        :param word_table: WordTable
        :return:
        """
        abstract_ids = []
        title_ids = []
        
        for i in range(len(abstract)):
            a_ids = [self.__convert_word2id(word) for word in abstract[i].split()]
            abstract_ids.append(a_ids)
            t_ids = [self.__convert_word2id(word) for word in title[i].split()]
            title_ids.append(t_ids) 
        
        return abstract_ids, title_ids
          
    
    def __numericize_data(self):
        a, t = self.__convert_text2ids(self.abstract, self.title)
        
        self.abstract_lens = [len(i) for i in a]
        self.titles_lens = [len(i) for i in t]
        
        self.__get_max_sequence_lengths(a,t)
        
        self.abstract_ids, self.title_ids = self.__tokenize_sentences(a,t)
        del a,t

# %%
train = TextSum_Dataset(train_abstracts, train_titles, max_vocab_size=50000, abstract_pad_len=200, title_pad_len=20, use_glove=False)

# %%
test = TextSum_Dataset(test_abstracts, test_titles, train.word2id_dict, train.id2word_dict, 
                      abstract_pad_len = train.abstract_pad_len, title_pad_len = train.title_pad_len, use_glove=False)

# %%
len(train.word2id_dict)
# Out:
# 50002

# %%
del train_abstracts, train_titles, test_abstracts, test_titles

# %%
class DataIterator:  
    def __init__(self, data, batch_size):
        self.data = data
        self.batch_size = batch_size
        self.data_iterator = self.make_random_iter()
        
    def next_batch(self):
        try:
            idxs = next(self.data_iterator)
        except StopIteration:
            self.data_iterator = self.make_random_iter()
            idxs = next(self.data_iterator)
            
        batch = [self.data[i] for i in idxs]
        batch_idxs = [idx for idx in idxs]
        return batch, batch_idxs

    def make_random_iter(self):
        splits = np.arange(self.batch_size, len(self.data), self.batch_size)
        it = np.split(np.random.permutation(range(len(self.data))), splits)[:-1]
        return iter(it)

# %%
train_ids = list(zip(train.abstract_ids, train.title_ids))
test_ids = list(zip(test.abstract_ids, test.title_ids))

# %%
train_data_iter = DataIterator(train_ids,128)
test_data_iter = DataIterator(test_ids,128)
deploy_data_iter = DataIterator(train_ids,1)

# %%
def prepare_model_dir():
    model_dir = os.getcwd() + '/'
    if not os.path.exists(model_dir + 'weights'):
        os.makedirs(model_dir + 'weights')
    return model_dir

# %%
def write_to_log(string,filename):
#     print(string)
    with open(filename,'a') as write_file:
        write_file.write(string + '\n')

# %%
def loop_function(prev, embedding, w, b, update_embedding=True):
    prev = tf.nn.xw_plus_b(prev, w, b)
    prev_symbol = tf.argmax(prev,1) #maybe 0 if not transpose
    emb_prev = tf.nn.embedding_lookup(embedding, prev_symbol)
    if not update_embedding:
        emb_prev = tf.stop_gradient(emb_prev)
    return

# %%
abstract_max_len = train.abstract_pad_len
title_max_len = train.title_pad_len

n_hidden = 150 
n_hidden_layers = 2
word_dim = glove_embedding_size
vocab_size = len(train.vocab)

learning_rate = 0.001
train_iters = 100000
keep_prob = 0.5

display_step = 200
val_interval = 1000
save_weights_interval = 1000
deploy_interval = 1000


device = '/gpu:0'

# %%
model_dir = prepare_model_dir()
tf.reset_default_graph()
sess = tf.InteractiveSession()

# %%
passage = tf.placeholder(tf.int32,[None, abstract_max_len])
#passage_lens = tf.placeholder(tf.int32,[None])
summary = tf.placeholder(tf.int64,[None, title_max_len])

dropout = tf.placeholder(tf.float32)
batch_size = tf.placeholder(tf.int32)
use_prev = tf.placeholder(tf.int32)

encoder_inputs = tf.unstack(passage, axis=1)
decoder_inputs = tf.unstack(summary, axis=1)
decoder_inputs = [tf.zeros_like(decoder_inputs[0], dtype=tf.int64, name='GO')] + decoder_inputs[:-1]

with tf.variable_scope('embedding'):
    embedding = tf.Variable(tf.truncated_normal(shape=[vocab_size, word_dim], stddev=1e-4))
    #embedding = tf.constant(glove_embedding_matrix, name='embeddings', dtype=tf.float32)
    
    emb_enc_inputs = [tf.nn.embedding_lookup(embedding, x)
                      for x in encoder_inputs]
    emb_dec_inputs = [tf.nn.embedding_lookup(embedding, x)
                      for x in decoder_inputs]

# %%
with tf.variable_scope('encoder'):
    enc_cell = tf.nn.rnn_cell.LSTMCell(n_hidden)
    enc_cell = tf.nn.rnn_cell.DropoutWrapper(enc_cell, output_keep_prob=dropout)
    #enc_cell = tf.nn.rnn_cell.MultiRNNCell([enc_cell]*n_hidden_layers)

    enc_state = enc_cell.zero_state(batch_size, dtype=tf.float32)
    h_states = []
    c_states = []
    
    for i in range(abstract_max_len):
        h, enc_state = enc_cell(emb_enc_inputs[i], enc_state)
        tf.get_variable_scope().reuse_variables()
#         h_states.append(enc_state.h)
#         c_states.append(enc_state.c)
    
#     h_states = tf.transpose(tf.stack(h_states),[1,0,2])
#     h_indices = tf.range(tf.shape(h_states)[0])*tf.shape(h_states)[1]+(passage_lens-1)
#     h_thought = tf.gather(tf.reshape(h_states,[-1,n_hidden]), h_indices)
    
#     c_states = tf.transpose(tf.stack(c_states),[1,0,2])
#     c_indices = tf.range(tf.shape(c_states)[0])*tf.shape(c_states)[1]+(passage_lens-1)
#     c_thought = tf.gather(tf.reshape(c_states,[-1,n_hidden]), c_indices)

w = tf.Variable(tf.truncated_normal(shape=[n_hidden, vocab_size], stddev=1e-4))
w_t = tf.transpose(w)
b = tf.Variable(tf.truncated_normal(shape=[vocab_size], stddev=1e-4))

with tf.variable_scope('decoder'):
    
    dec_cell = tf.nn.rnn_cell.LSTMCell(n_hidden)
    dec_cell = tf.nn.rnn_cell.DropoutWrapper(dec_cell, output_keep_prob=dropout)
    dec_cell = tf.nn.rnn_cell.OutputProjectionWrapper(dec_cell, vocab_size)
    
    dec_input_state =  enc_state
    dec_outputs, dec_state = tf.nn.seq2seq.rnn_decoder(emb_dec_inputs, dec_input_state,
                                               dec_cell)

with tf.variable_scope('loss'):
    weights = [tf.ones_like(label,dtype=tf.float32) for label in decoder_inputs]
    loss = tf.nn.seq2seq.sequence_loss(dec_outputs, decoder_inputs, weights, vocab_size)

with tf.variable_scope('prediction'):
    accuracy = 0
    generated_tokens = []
    for i,output in enumerate(dec_outputs):
        output = tf.nn.softmax(output)
        pred_tokens = tf.argmax(output, axis=1)
        generated_tokens.append(pred_tokens)
        
        label = tf.slice(summary,[0,i],[-1,1])
        accuracy += tf.reduce_mean(tf.cast(tf.equal(pred_tokens,label), tf.float32))
    accuracy = accuracy / float(title_max_len)
    
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
sess.run(tf.global_variables_initializer())

# %%
log_file = model_dir + 'seq2seq_log.txt'
saver = tf.train.Saver(max_to_keep=100)
log=open(log_file,'w')
log.close()

# %%
for train_iter in range(train_iters):
    train_iter +=1
    train_batch, _ = train_data_iter.next_batch()
    train_abstract, train_title, train_abs_len = zip(*train_batch)
    if train_iter==1:
        init_feed_dict = {passage:train_abstract,
                          summary: train_title,
                          dropout: 1.0,
                          batch_size: train_data_iter.batch_size}
        
        init_loss, init_acc = tuple(sess.run([loss, accuracy], 
                                            feed_dict=init_feed_dict))
        log_output = ("Iter {}, accuracy = {:.4f}, loss = {:.6f}").format(train_iter, init_acc, init_loss)
        
        print(log_output)
        write_to_log(log_output, log_file)
    
    train_feed_dict = {passage:train_abstract, 
                       summary: train_title,
                       dropout: keep_prob,
                       batch_size: train_data_iter.batch_size}
    
    sess.run(optimizer, feed_dict=train_feed_dict)
    
    if train_iter % display_step ==0:
        disp_feed_dict = {passage:train_abstract,
                          summary: train_title,
                          dropout: 1.0,
                          batch_size: train_data_iter.batch_size}
        
        train_loss, train_acc = tuple(sess.run([loss, accuracy], 
                                               feed_dict=disp_feed_dict))
        
        log_output = ("Iter {}, accuracy = {:.4f}, loss = {:.6f}").format(train_iter, train_acc, train_loss)
        print(log_output)
        write_to_log(log_output, log_file)
    
    if test_data_iter !=None and train_iter% val_interval==0:
        test_batch, _ = test_data_iter.next_batch()
        test_abstract, test_title, test_abs_len = zip(*test_batch)
        test_feed_dict = {passage:test_abstract,
                          summary: test_title,
                          dropout: 1.0,
                          batch_size: test_data_iter.batch_size}
        
        test_loss, test_acc = tuple(sess.run([loss, accuracy], 
                                             feed_dict=test_feed_dict))
        
        log_output = ("Iter {}, VALIDATION -- accuracy = {:.4f}, loss = {:.6f}").format(train_iter, test_acc, test_loss)
        print(log_output)
        write_to_log(log_output, log_file)
    
    if deploy_data_iter !=None and train_iter % deploy_interval==0:
        deploy_batch, _ = deploy_data_iter.next_batch()
        deploy_abstract, deploy_title, dep_abs_lens = zip(*deploy_batch)
        
        model_pred = sess.run(generated_tokens, feed_dict={passage: deploy_abstract,
                                                           summary: deploy_title,
                                                           dropout: 1.0,
                                                           batch_size: deploy_data_iter.batch_size})
        
        label_ids = deploy_title[0]
        pred_ids = [x[0] for x in model_pred]
        log_output = ''
        if train.id2word_dict != None:
            log_output = ('PASSAGE\n{}\nModel Pred = {}\nGround Truth = {}\n'
                          .format(' '.join([train.id2word_dict[idx] for idx in deploy_abstract[0]]),
                                  ' '.join([train.id2word_dict[idx] for idx in pred_ids]),
                                  ' '.join([train.id2word_dict[idx] for idx in label_ids]))
                         )
        else:
            log_output = ('Model Pred = {}, Ground Truth = {}'
                          .format(pred_ids, label_ids)
                         )
        print(log_output)
        write_to_log(log_output, log_file)
    
    if train_iter% save_weights_interval ==0:
        weights_dir = model_dir + "weights/seq2seq_weights_iter--{}.ckpt".format(train_iter)
        save_path = saver.save(sess,weights_dir)
        save_string = "Model saved in file: {}".format(save_path)
        print(save_string)
        write_to_log(save_string, log_file)
# Out:
# Iter 1, accuracy = 0.0001, loss = 10.819901
# Iter 200, accuracy = 0.1541, loss = 4.206182
# Iter 400, accuracy = 0.1591, loss = 3.578858
# Iter 600, accuracy = 0.1736, loss = 2.922408
# Iter 800, accuracy = 0.1725, loss = 2.260313
# Iter 1000, accuracy = 0.1558, loss = 1.934989
# Iter 1000, VALIDATION -- accuracy = 0.1785, loss = 1.944571
# PASSAGE
# 22q11 . 2 deletion syndrome 22q11 . 2ds is a multisystemic disorder with high phenotypic variability . underdiagnosis in adults is common and recognition of facial dysmorphic features can be affected by age and ethnicity . this study aims to determine the prevalence of undiagnosed 22q11 . 2ds in adult chinese patients with UNK anomalies and to delineate their facial UNK and extracardiac manifestations . we recruited consecutively 156 patients with UNK anomalies in an adult congenital heart disease chd clinic in hong kong and screened for 22q11 . 2ds using UNK and fluorescence insitu hybridization . assessment for dysmorphic features was performed by a cardiologist at initial screening and then by a clinical UNK upon result disclosure . clinical photographs were taken and childhood photographs collected . eighteen patients 11 . 5 were diagnosed with 22q11 . 2ds translating into 1 previously unrecognized diagnosis of 22q11 . 2ds in every 10 adult patients with UNK anomalies . while dysmorphic features were detected by our clinical UNK in all patients only twothirds were considered dysmorphic by our cardiologist upon first assessment . evolution of facial dysmorphic features was noted with age . extracardiac manifestations included velopharyngeal incompetence or cleft palate
# Model Pred = PAD UNK of bacterial . 2 temperature in adult chinese patients with UNK weight implications in extraction care . PAD
# Ground Truth = UNK of 22q11 . 2 deletion in adult chinese patients with UNK anomalies implications in transitional care . PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--1000.ckpt
# Iter 1200, accuracy = 0.1930, loss = 1.609255
# Iter 1400, accuracy = 0.1549, loss = 1.488688
# Iter 1600, accuracy = 0.2052, loss = 1.180087
# Iter 1800, accuracy = 0.1729, loss = 1.072663
# Iter 2000, accuracy = 0.1668, loss = 0.962659
# Iter 2000, VALIDATION -- accuracy = 0.1897, loss = 0.912719
# PASSAGE
# free fatty acids ffas are dietary nutrients which act as ligands for ffas receptors . gproteincoupled receptor 120 gpr120 and gpr40 are activated by long and medium chain ffas . in the present study we investigated the role of the gpr120 and gpr40 in cell motile activity stimulated by UNK in rat liver epithelial UNK cells . cells were treated with UNK at a concentration of 10μm every 24h for UNK . the expression levels of the gpr120 and gpr40 genes in UNK cells treated UNK were significantly higher than those in untreated cells . in cell motility assay the cell motile activity of UNK cells was markedly elevated by UNK compared with untreated cells . to evaluate the effects of gpr120 on the cell motile activity by UNK we established gpr120 knockdown cells from UNK cells . the cell motile activity stimulated by UNK was significantly suppressed by gpr120 knockdown . in addition a potent gpr40 antagonist UNK enhanced the cell motile activity by UNK . these results suggest that opposite effects of gpr120 and gpr40 may be involved in the cell motile activity stimulated by UNK in UNK cells . PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD PAD effects of PAD and saudi on cell PAD activity induced by UNK in liver epithelial cells . PAD
# Ground Truth = opposite effects of gpr120 and gpr40 on cell motile activity induced by UNK in liver epithelial cells . PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--2000.ckpt
# Iter 2200, accuracy = 0.1521, loss = 0.797600
# Iter 2400, accuracy = 0.1598, loss = 0.847316
# Iter 2600, accuracy = 0.1688, loss = 0.623804
# Iter 2800, accuracy = 0.1649, loss = 0.655960
# Iter 3000, accuracy = 0.1767, loss = 0.556493
# Iter 3000, VALIDATION -- accuracy = 0.1589, loss = 0.529139
# PASSAGE
# UNK UNK ammonium chitosan chloride UNK is UNK chitosan cs derivative which can be obtained by the reaction between UNK trimethyl ammonium chloride eta and cs . the preparation parameters for the synthesis of UNK were optimized by orthogonal experimental design . eta was successfully grafted into the free amino group of cs . grafting of eta with cs had great effect on the crystal structure of UNK which was confirmed by the xrd results . UNK displayed higher capability to form nanoparticles by crosslinking with negatively charged sodium UNK tpp . UNK UNK loaded UNK nanoparticles were positively charged and were spherical in shape with average particle size of 200 nm . more efficient drug encapsulation efficiency and loading capacity were obtained for UNK in comparison with cs however UNK nanoparticles displayed faster release rate due to its UNK properties . the results suggest that UNK is a promising cs derivative for the encapsulation of hydrophilic drugs in obtaining sustained release of drugs . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD synthesis and characterization of chitosan quaternary ammonium salt and its application as drug carrier for ribavirin . PAD PAD
# Ground Truth = synthesis and characterization of chitosan quaternary ammonium salt and its application as drug carrier for ribavirin . PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--3000.ckpt
# Iter 3200, accuracy = 0.1667, loss = 0.503617
# Iter 3400, accuracy = 0.1595, loss = 0.498573
# Iter 3600, accuracy = 0.1660, loss = 0.389721
# Iter 3800, accuracy = 0.1990, loss = 0.395470
# Iter 4000, accuracy = 0.1869, loss = 0.415331
# Iter 4000, VALIDATION -- accuracy = 0.1761, loss = 0.301777
# PASSAGE
# UNK disease is caused by an inherited deficiency of the enzyme UNK resulting in exercise intolerance from childhood and acute crises of early fatigue and contractures . in severe cases these manifestations can be accompanied by rhabdomyolysis UNK and fatal renal failure . diagnosis of UNK disease is based on clinical diagnostic tests together with an absence of UNK activity in skeletal muscle biopsies and genetic analysis of the UNK gene UNK . the recently reported association between UNK and rac1 gtpase in a t lymphocyte cell line prompted us to study UNK expression in white blood cells wbcs from 20 healthy donors and 30 UNK patients by flow cytometry using a UNK UNK antibody . we found that t lymphocytes expressed UNK in healthy donors but expression was significantly lower in UNK patients p0 . 001 . UNK mrna levels were also lower in white blood cells from UNK patients . nevertheless in 13 of patients who were either heterozygotes or homozygotes for the most common UNK pathogenic mutation among caucasians p . UNK the percentage of UNK white blood cells was not different compared with the control group . our findings suggest that analysis of UNK expression in
# Model Pred = PAD UNK expression analysis in white blood cells a complementary tool for diagnosing UNK disease PAD PAD PAD PAD PAD
# Ground Truth = UNK expression analysis in white blood cells a complementary tool for diagnosing UNK disease PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--4000.ckpt
# Iter 4200, accuracy = 0.1720, loss = 0.331873
# Iter 4400, accuracy = 0.1782, loss = 0.286025
# Iter 4600, accuracy = 0.1322, loss = 0.292144
# Iter 4800, accuracy = 0.1916, loss = 0.248987
# Iter 5000, accuracy = 0.1687, loss = 0.211686
# Iter 5000, VALIDATION -- accuracy = 0.2076, loss = 0.232364
# PASSAGE
# development of new fruit cultivars is dependent on genetic resource collections such as those at the UNK garden of the institute of UNK and UNK near UNK kazakhstan . the pear germplasm collection of the UNK garden contains 615 cultivars and three species . in vitro cold storage of the collection would provide additional security to the field collection . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD growth medium alterations improve in vitro cold storage of pear germplasm . PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = growth medium alterations improve in vitro cold storage of pear germplasm . PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--5000.ckpt
# Iter 5200, accuracy = 0.1703, loss = 0.258094
# Iter 5400, accuracy = 0.1803, loss = 0.201676
# Iter 5600, accuracy = 0.1641, loss = 0.177796
# Iter 5800, accuracy = 0.1597, loss = 0.209063
# Iter 6000, accuracy = 0.1441, loss = 0.175756
# Iter 6000, VALIDATION -- accuracy = 0.1881, loss = 0.167548
# PASSAGE
# in mammals the auditory system which includes the cochlea has a very complex structure harboring many types of cells performing different functions . among these cells are the auditory hair cells hcs which are terminally and well differentiated unique cells which have lost their regenerative potential after development . the auditory hcs are easily damaged by aging as well as during episodes of ototoxicity and acoustic trauma . hcs damages typically occur in the early stage of injury and can result a permanent hearing loss . recently there have been tremendous developments from stem cells scs research involving sensorineural hearing loss but several limitations and obstacles persist in allowing these developments from continuing onto clinical applications . this review discusses the recent advances in sc research in sensorineural hearing loss with the subsequent sections discussing the possible hurdles and limitations that currently preclude their clinical application . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD stem cell therapy for sensorineural hearing loss still PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = stem cell therapy for sensorineural hearing loss still alive PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--6000.ckpt
# Iter 6200, accuracy = 0.1557, loss = 0.190039
# Iter 6400, accuracy = 0.1913, loss = 0.163722
# Iter 6600, accuracy = 0.1587, loss = 0.110151
# Iter 6800, accuracy = 0.1896, loss = 0.155638
# Iter 7000, accuracy = 0.1565, loss = 0.134220
# Iter 7000, VALIDATION -- accuracy = 0.1653, loss = 0.107794
# PASSAGE
# although bone involvement associated with cyst hydatid is rarely seen it can cause unintended results such as high recurrence rate infection sepsis or amputation of relevant extremity . because of this reason its treatment is difficult and disputed . in the case of UNK bone cyst hydatid in right femur along with albendazole treatment result of UNK cyst surgically and its treatment with teicoplanin with added bone cement is given . in conclusion since the offered treatment method both supports bone in terms of mechanical aspect and also can prevent secondary infection the method is thought to be a good and safe treatment approach . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD treatment of UNK cyst hydatid involvement in right femur with teicoplanin added bone cement and albendazole . PAD PAD
# Ground Truth = treatment of UNK cyst hydatid involvement in right femur with teicoplanin added bone cement and albendazole . PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--7000.ckpt
# Iter 7200, accuracy = 0.1664, loss = 0.088933
# Iter 7400, accuracy = 0.1830, loss = 0.111431
# Iter 7600, accuracy = 0.1799, loss = 0.071980
# Iter 7800, accuracy = 0.1457, loss = 0.073122
# Iter 8000, accuracy = 0.1636, loss = 0.065225
# Iter 8000, VALIDATION -- accuracy = 0.1488, loss = 0.085947
# PASSAGE
# green tea and hibiscus are widely consumed as traditional beverages in yemen and some regional countries . they are relatively cheap and the belief is that they improve health state and cure many diseases . the aim of this study was to evaluate the potential protective and antibacterial activity of these two famous plants in vitro through measuring their antibacterial activity and in vivo through measuring nonenzymatic kidney markers dysfunction after induction of nephrotoxicity by gentamicin . gram positive bacteria like mrsa methicillin resistant staphylococcus aureus were isolated from hospitalized patients different sources pus and wound and gram negative bacteria including e . coli and p . aeruginosa were used in vitro study . in addition the efficacy of these plants was assessed in vivo through measuring nonenzymatic kidney markers including s . creatinine and s . urea . green tea was shown antimicrobial activity against mrsa with inhibition zone 19 . 67 ± 0 . 33 mm and mic 1 . 25 ± 0 . 00 mgml compared with standard reference vancomycin 18 . 00 ± 0 . 00 mgml . hibiscus did not exhibit a similar effect . both hibiscus and green UNK groups had nephroprotective effects as
# Model Pred = PAD evaluation of the potential nephroprotective and antimicrobial effect of camellia sinensis leaves versus hibiscus UNK in vivo and in
# Ground Truth = evaluation of the potential nephroprotective and antimicrobial effect of camellia sinensis leaves versus hibiscus UNK in vivo and in vitro
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--8000.ckpt
# Iter 8200, accuracy = 0.1705, loss = 0.066324
# Iter 8400, accuracy = 0.1653, loss = 0.041354
# Iter 8600, accuracy = 0.1884, loss = 0.059215
# Iter 8800, accuracy = 0.1850, loss = 0.063735
# Iter 9000, accuracy = 0.1975, loss = 0.043090
# Iter 9000, VALIDATION -- accuracy = 0.1664, loss = 0.094751
# PASSAGE
# voltagegated potassium kv channels are involved in action potential ap repolarization in excitable cells . exogenous application of UNK lipids such as arachidonic acid aa regulates the gating of kv channels . whether UNK lipids released under physiological conditions have an impact on neuronal coding through this mechanism is unknown . we show that aa released in an activitydependent manner from postsynaptic hippocampal ca3 pyramidal cells acts as retrograde messenger inducing a robust facilitation of mossy fiber mf synaptic transmission over several minutes . aa acts by broadening presynaptic aps through the direct modulation of kv channels . this form of shortterm plasticity can be triggered when postsynaptic cell fires with physiologically relevant patterns and sets the threshold for the induction of the presynaptic form of longterm potentiation ltp at hippocampal mf synapses . hence direct modulation of presynaptic kv channels by activitydependent release of lipids serves as a physiological mechanism for tuning synaptic transmission . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD membrane lipids tune synaptic transmission by direct modulation of presynaptic potassium channels . PAD PAD PAD PAD PAD PAD
# Ground Truth = membrane lipids tune synaptic transmission by direct modulation of presynaptic potassium channels . PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--9000.ckpt
# Iter 9200, accuracy = 0.1849, loss = 0.041473
# Iter 9400, accuracy = 0.1852, loss = 0.052025
# Iter 9600, accuracy = 0.1765, loss = 0.026402
# Iter 9800, accuracy = 0.1700, loss = 0.039223
# Iter 10000, accuracy = 0.1891, loss = 0.050801
# Iter 10000, VALIDATION -- accuracy = 0.1555, loss = 0.071809
# PASSAGE
# UNK is a mainly nuclear catalytic subunit of the human exosome complex containing UNK UNK and UNK pin active domains . mutations in UNK have been found in ∼10 of patients with multiple myeloma mm . here we show that these mutations interfere with UNK UNK activity . yeast harboring corresponding mutations in UNK show growth inhibition and changes in nuclear rna metabolism typical for exosome dysfunction . construction of a conditional UNK knockout in the chicken dt40 cell line revealed that UNK is essential for cell survival indicating that its function cannot be replaced by other UNK nucleases UNK and UNK . moreover UNK cells in which depletion of endogenous wildtype UNK was complemented with exogenously expressed mm UNK mutants proliferate at a slower rate and exhibit aberrant rna metabolism . importantly mm mutations are synthetically lethal with the UNK pin domain catalytic mutation both in yeast and human cells . since mutations in pin domain alone have little effect on cell physiology our results predict the UNK pin domain as a potential drug target for mm patients with UNK mutations . it is an interesting example of intramolecular synthetic lethality with putative therapeutic potential in humans . PAD
# Model Pred = PAD multiple UNK UNK mutations cause perturbations in cellular rna metabolism and suggest UNK pin domain as a potential drug
# Ground Truth = multiple UNK UNK mutations cause perturbations in cellular rna metabolism and suggest UNK pin domain as a potential drug target
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--10000.ckpt
# Iter 10200, accuracy = 0.1676, loss = 0.035023
# Iter 10400, accuracy = 0.1783, loss = 0.033721
# Iter 10600, accuracy = 0.1302, loss = 0.042962
# Iter 10800, accuracy = 0.1622, loss = 0.023711
# Iter 11000, accuracy = 0.1717, loss = 0.023356
# Iter 11000, VALIDATION -- accuracy = 0.1679, loss = 0.021319
# PASSAGE
# the purpose of this report was to evaluate the role antivegf in management of UNK secondary to ocular toxoplasmosis . young female diagnosed as a case of bilateral ocular toxoplasmosis presented with complaints of diminution of vision in the right eye . fundus examination showed an active UNK adjacent to toxoplasmosis scar . in view of active UNK patient was administered intravitreal ranibizumab . a total of 2 injections of intravitreal ranibizumab were given . fundus showed a scarred UNK adjacent to the toxoplasma scar with no clinical signs of activity . antivegf therapy has been successfully used to improve visual and anatomical outcome in UNK deleted UNK secondary to toxoplasmosis . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD paediatric choroidal neovascular membrane secondary to toxoplasmosis treated successfully with antivascular endothelial growth factor . PAD PAD PAD PAD
# Ground Truth = paediatric choroidal neovascular membrane secondary to toxoplasmosis treated successfully with antivascular endothelial growth factor . PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--11000.ckpt
# Iter 11200, accuracy = 0.1505, loss = 0.030320
# Iter 11400, accuracy = 0.2138, loss = 0.038206
# Iter 11600, accuracy = 0.1664, loss = 0.017679
# Iter 11800, accuracy = 0.1420, loss = 0.013074
# Iter 12000, accuracy = 0.1756, loss = 0.019553
# Iter 12000, VALIDATION -- accuracy = 0.1373, loss = 0.030170
# PASSAGE
# in this study novel UNK ultraviolet lightemitting diodes UNK were fabricated using wafer bonding laser liftoff dry etching textured surface and interconnection techniques . placing pn electrodes on the same side minimized the absorption caused by electrodes in conventional vertical injection lightemitting diodes UNK and the current spreading was improved . the light output power 700 ma of the UNK was enhanced by 18 . 3 compared with that of the UNK and the external quantum efficiency eqe of the UNK was also relatively enhanced by 20 . 0 compared with that of a reference device . when the current operations were 1500 ma the enhancements of the light output power and eqe were 27 . 4 and 27 . 2 respectively . additionally the efficiency UNK was improved by more than 15 at the same current level . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD novel UNK led structure adopted micro UNK surface to compare with conventional vertical leds in ultraviolet light . PAD
# Ground Truth = novel UNK led structure adopted micro UNK surface to compare with conventional vertical leds in ultraviolet light . PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--12000.ckpt
# Iter 12200, accuracy = 0.1379, loss = 0.051073
# Iter 12400, accuracy = 0.1555, loss = 0.028593
# Iter 12600, accuracy = 0.1737, loss = 0.006492
# Iter 12800, accuracy = 0.1437, loss = 0.014613
# Iter 13000, accuracy = 0.1471, loss = 0.012876
# Iter 13000, VALIDATION -- accuracy = 0.1729, loss = 0.014754
# PASSAGE
# the use of intensity modulated radiation therapy imrt has allowed for the administration of high doses to retroperitoneal sarcomas UNK while limiting toxicity to adjacent organs . the purpose of our study is to assess the outcome and toxicities of patients with UNK treated with neoadjuvant external beam radiation ebrt therapy using imrt . this is a retrospective study of 21 patients treated with preoperative imrt for primary or recurrent UNK between 2005 and 2011 . overall survival os and local recurrence free survival UNK were computed using the kaplanmeier method logrank test . acute and chronic toxicities were assessed using the UNK v . 3 criteria . the actuarial 2 and 3year os was 66 for both and the 5year os was 51 . as for UNK it was 57 at 2 and 3year and 51 for the 5year UNK . factors predictive for local control were microscopically negative margins p 0 . 022 a median tumor diameter 15 cm p 0 . 007 and pathology of liposarcoma p 0 . 021 . furthermore patients treated for recurrent disease UNK worse p 0 . 04 in local control than patients treated for primary disease . as for os patients
# Model Pred = PAD preoperative intensity modulated radiation therapy for retroperitoneal sarcoma . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = preoperative intensity modulated radiation therapy for retroperitoneal sarcoma . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--13000.ckpt
# Iter 13200, accuracy = 0.1535, loss = 0.016081
# Iter 13400, accuracy = 0.1865, loss = 0.016792
# Iter 13600, accuracy = 0.1654, loss = 0.009282
# Iter 13800, accuracy = 0.1685, loss = 0.006274
# Iter 14000, accuracy = 0.1684, loss = 0.010537
# Iter 14000, VALIDATION -- accuracy = 0.1655, loss = 0.031209
# PASSAGE
# singlemolecule localization microscopy has been widely applied to count the number of biological molecules within a certain structure . the percentage of molecules that are detected significantly affects the interpretation of data . among many factors that affect this percentage the polarization state of the excitation light is often neglected or at least UNK in publications . we demonstrate by simulation and experiment that the number of molecules detected can be different from 40 up to 100 when using circularly or linearly polarized excitation light . this is determined mainly by the number of photons emitted by single fluorescent molecule namely the choice of fluorescence proteins and the background noise in the system namely the illumination scheme . this difference can be further exaggerated or mitigated by various fixation methods magnification and camera settings we conclude that the final choice between circularly or linearly polarized excitation light should be made experimentally based on the signal to noise ratio of the system . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD polarization of excitation light influences molecule counting in singlemolecule localization microscopy . PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = polarization of excitation light influences molecule counting in singlemolecule localization microscopy . PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--14000.ckpt
# Iter 14200, accuracy = 0.1816, loss = 0.010177
# Iter 14400, accuracy = 0.1544, loss = 0.009640
# Iter 14600, accuracy = 0.1558, loss = 0.018028
# Iter 14800, accuracy = 0.1283, loss = 0.007857
# Iter 15000, accuracy = 0.1543, loss = 0.006997
# Iter 15000, VALIDATION -- accuracy = 0.1737, loss = 0.046854
# PASSAGE
# recent advances in behavioral genetics suggest a modest relationship among certain gene variants early childhood experiences and criminal behavior . although scientific research examining this link is still at an early stage genetic data are already being introduced in criminal trials . however the extent to which such evidence is likely to affect UNK decisions has not been explored . in the present study a representative sample of the u . s . population n 250 received a vignette describing an apparently impulsive homicide accompanied by one of four explanations of the UNK impulsivity childhood abuse genetic predisposition childhood abuse and genetic predisposition or simple impulsive behavior . the participants were asked to identify the crime that the UNK had committed and to select an appropriate sentence range . evidence of genetic predisposition did not affect the crime of which the UNK was UNK or the sentence . however participants who received the abuse or genetic abuse explanation imposed longer prison sentences . paradoxically the genetic and genetic abuse conditions engendered the greatest fear of the UNK . these findings should UNK concerns that genetic evidence in criminal UNK will be overly persuasive to UNK but should raise questions about
# Model Pred = PAD impact of behavioral genetic evidence on the adjudication of criminal behavior . PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = impact of behavioral genetic evidence on the adjudication of criminal behavior . PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--15000.ckpt
# Iter 15200, accuracy = 0.1595, loss = 0.002653
# Iter 15400, accuracy = 0.1657, loss = 0.007393
# Iter 15600, accuracy = 0.1628, loss = 0.005066
# Iter 15800, accuracy = 0.1734, loss = 0.015159
# Iter 16000, accuracy = 0.1719, loss = 0.010448
# Iter 16000, VALIDATION -- accuracy = 0.1503, loss = 0.016341
# PASSAGE
# nausea and vomiting are common symptoms in palliative care and can be highly distressing to patients . this review discusses the mechanisms by which nausea and vomiting are triggered using case studies to highlight the most common scenarios and how to manage these . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD management of nausea and vomiting in palliative care . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = management of nausea and vomiting in palliative care . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--16000.ckpt
# Iter 16200, accuracy = 0.2149, loss = 0.007601
# Iter 16400, accuracy = 0.1503, loss = 0.001075
# Iter 16600, accuracy = 0.1560, loss = 0.022901
# Iter 16800, accuracy = 0.1733, loss = 0.018037
# Iter 17000, accuracy = 0.1462, loss = 0.005611
# Iter 17000, VALIDATION -- accuracy = 0.1774, loss = 0.005489
# PASSAGE
# diabetic macular edema dme is a UNK complication of diabetic retinopathy . the current practice of management is a trial and error method of using intravitreal antivascular endothelial growth factor vegf or steroids to treat the patient and watch the response . however if the patients genetic profile helps us choose appropriate medicine it would help UNK treatment option for each patient . this forms the basis of our study . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD differential systemic gene expression profile in patients with diabetic macular edema responders versus nonresponders to standard treatment . PAD
# Ground Truth = differential systemic gene expression profile in patients with diabetic macular edema responders versus nonresponders to standard treatment . PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--17000.ckpt
# Iter 17200, accuracy = 0.1773, loss = 0.005433
# Iter 17400, accuracy = 0.1622, loss = 0.003203
# Iter 17600, accuracy = 0.1391, loss = 0.004717
# Iter 17800, accuracy = 0.1590, loss = 0.008225
# Iter 18000, accuracy = 0.1760, loss = 0.011067
# Iter 18000, VALIDATION -- accuracy = 0.1714, loss = 0.012854
# PASSAGE
# inorganic arsenic is methylated in the body by arsenic iii methyltransferase UNK . arsenic methylation is thought to play a role in UNK epigenetic phenomena including aberrant dna and histone methylation . however it is unclear whether the promoter of the UNK gene which codes for UNK is differentially methylated as a function of arsenic exposure . in this study we evaluated UNK promoter methylation according to exposure assessed by urinary arsenic excretion in a stratified random sample of 48 participants from the strong heart study who had urine arsenic measured at baseline and dna available from 1989 to 1991 and UNK . for this study all data are from the UNK visit . we measured UNK promoter methylation at its 48 cpg loci by UNK sequencing . we compared mean methylation at each cpg locus by arsenic exposure group using linear regression adjusted for study centre age and sex . a hypomethylated region in the UNK promoter was associated with higher arsenic exposure . in vitro arsenic induced UNK promoter hypomethylation and it increased UNK expression in human peripheral blood mononuclear cells . these findings may suggest that arsenic exposure influences the epigenetic regulation of a major arsenic metabolism
# Model Pred = PAD differential methylation of the arsenic iii methyltransferase promoter according to arsenic exposure . PAD PAD PAD PAD PAD PAD
# Ground Truth = differential methylation of the arsenic iii methyltransferase promoter according to arsenic exposure . PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--18000.ckpt
# Iter 18200, accuracy = 0.1609, loss = 0.017950
# Iter 18400, accuracy = 0.1764, loss = 0.010013
# Iter 18600, accuracy = 0.1599, loss = 0.006788
# Iter 18800, accuracy = 0.1889, loss = 0.004726
# Iter 19000, accuracy = 0.1432, loss = 0.005862
# Iter 19000, VALIDATION -- accuracy = 0.1655, loss = 0.005339
# PASSAGE
# this article reviews recent evidence and other earlier relevant articles regarding early intervention studies for children with autism spectrum disorder asd . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD a review of evidencebased early intervention for behavioural problems in children with autism spectrum disorder the core components of
# Ground Truth = a review of evidencebased early intervention for behavioural problems in children with autism spectrum disorder the core components of effective
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--19000.ckpt
# Iter 19200, accuracy = 0.1667, loss = 0.004311
# Iter 19400, accuracy = 0.1983, loss = 0.005238
# Iter 19600, accuracy = 0.1764, loss = 0.006231
# Iter 19800, accuracy = 0.1755, loss = 0.003989
# Iter 20000, accuracy = 0.1659, loss = 0.008567
# Iter 20000, VALIDATION -- accuracy = 0.1771, loss = 0.006781
# PASSAGE
# to identify serum microrna mirna as diagnostic and prognostic biomarkers for acute pancreatitis ap . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD identification of serum micrornas as diagnostic and prognostic biomarkers for acute pancreatitis . PAD PAD PAD PAD PAD PAD
# Ground Truth = identification of serum micrornas as diagnostic and prognostic biomarkers for acute pancreatitis . PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--20000.ckpt
# Iter 20200, accuracy = 0.1705, loss = 0.007543
# Iter 20400, accuracy = 0.1749, loss = 0.000831
# Iter 20600, accuracy = 0.1402, loss = 0.002937
# Iter 20800, accuracy = 0.1516, loss = 0.003575
# Iter 21000, accuracy = 0.1865, loss = 0.001118
# Iter 21000, VALIDATION -- accuracy = 0.1860, loss = 0.008150
# PASSAGE
# plants have evolved strategies and mechanisms to detect and respond to pathogen attack . different organs of the same plant may be subjected to different environments e . g . aboveground versus belowground and pathogens with different lifestyles . accordingly plants commonly need to tailor defense strategies in an organspecific manner . phytophthora infestans causal agent of potato late blight disease infects both aboveground foliage and belowground tubers . we examined the efficacy of transgene rb known for conferring foliar late blight resistance in defending against tuber late blight disease . our results indicate that the presence of the transgene has a positive yet only marginally significant effect on tuber disease resistance on average . however a significant association between transgene transcript levels and tuber resistance was established for specific transformed lines in an agedependent manner with higher transcript levels indicating enhanced tuber resistance . thus rb has potential to function in both foliage and tuber to impart late blight resistance . our data suggest that organspecific resistance might result directly from transcriptional regulation of the resistance gene itself . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD potato tuber blight resistance phenotypes correlate with rb transgene transcript levels in an agedependent manner . PAD PAD PAD
# Ground Truth = potato tuber blight resistance phenotypes correlate with rb transgene transcript levels in an agedependent manner . PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--21000.ckpt
# Iter 21200, accuracy = 0.1507, loss = 0.009089
# Iter 21400, accuracy = 0.1669, loss = 0.005568
# Iter 21600, accuracy = 0.1498, loss = 0.006746
# Iter 21800, accuracy = 0.1774, loss = 0.015708
# Iter 22000, accuracy = 0.1659, loss = 0.004027
# Iter 22000, VALIDATION -- accuracy = 0.1594, loss = 0.012069
# PASSAGE
# hematopoietic stem cell transplantation hsct can be curative for children with various malignant and nonmalignant conditions . access to suitable unrelated living donors UNK or unrelated cord blood ucb may be limited for certain ethnic backgrounds . we therefore determined the impact of ethnicity upon donor availability in a pediatric cohort referred for allogeneic hsct to a single canadian transplant center . among 252 eligible patients 58 23 . 0 had suitable family donors . of 161 patients with combined UNK and ucb searches 78 48 . 4 had a suitable UNK whereas 143 88 . 8 had suitable ucb . the probability of finding a suitable UNK differed significantly by ethnicity p0 . 007 . nonwhite patients were significantly less likely to have suitable UNK odds ratio or 0 . 35 95 confidence interval ci 0 . 170 . 69 p0 . 003 compared with white patients but were equally likely to have suitable ucb or 1 . 02 95 ci 0 . 362 . 89 p0 . 97 . although ethnic disparities exist in pediatric patients access to UNK for hsct they are narrowed by the availability of international ucb registries . these findings however also highlight the
# Model Pred = PAD impact of ethnicity on donor search results for children requiring stem cell transplantation . PAD PAD PAD PAD PAD
# Ground Truth = impact of ethnicity on donor search results for children requiring stem cell transplantation . PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--22000.ckpt
# Iter 22200, accuracy = 0.1618, loss = 0.004366
# Iter 22400, accuracy = 0.1832, loss = 0.006079
# Iter 22600, accuracy = 0.1833, loss = 0.000015
# Iter 22800, accuracy = 0.1903, loss = 0.003975
# Iter 23000, accuracy = 0.1648, loss = 0.006250
# Iter 23000, VALIDATION -- accuracy = 0.2047, loss = 0.006296
# PASSAGE
# methods for altering the sequence of endogenous drosophila melanogaster genes remain laborintensive . we have tested a relatively simple strategy that enables the introduction of engineered mutations in the vicinity of existing UNK . this method was used to generate useful alleles of the UNK gene which produces a noncoding rna involved in dosage compensation . the desired change was first introduced into a genomic clone of UNK and transgenic flies were generated that carry this sequence in a UNK . targeted transposition was then used to move the UNK into UNK . remobilization of the targeted insertion produced large numbers of offspring carrying chromosomes that had precisely introduced the engineered sequences into UNK . we postulate that this occurred by gap repair using the UNK on the sister chromatid as template . this strategy was used to introduce six ms2 loops into the UNK gene UNK enabling detection of UNK rna by a UNK fusion protein in embryos . the UNK remains under the control of the authentic promoter and within the correct genomic context features expected to contribute to normal UNK function . the ability to replace relatively large blocks of sequence suggests that this method will be
# Model Pred = PAD generation of a useful UNK allele by targeted gene conversion . PAD PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = generation of a useful UNK allele by targeted gene conversion . PAD PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--23000.ckpt
# Iter 23200, accuracy = 0.1564, loss = 0.007057
# Iter 23400, accuracy = 0.1752, loss = 0.005997
# Iter 23600, accuracy = 0.1580, loss = 0.004560
# Iter 23800, accuracy = 0.1462, loss = 0.002416
# Iter 24000, accuracy = 0.1454, loss = 0.009476
# Iter 24000, VALIDATION -- accuracy = 0.1344, loss = 0.006805
# PASSAGE
# to report the profile of microbial keratitis occurring after corneal collagen crosslinking cxl in keratoconus patients . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD profile of microbial keratitis after corneal collagen crosslinking . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = profile of microbial keratitis after corneal collagen crosslinking . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--24000.ckpt
# Iter 24200, accuracy = 0.1759, loss = 0.001693
# Iter 24400, accuracy = 0.1836, loss = 0.004263
# Iter 24600, accuracy = 0.1576, loss = 0.004779
# Iter 24800, accuracy = 0.1470, loss = 0.007078
# Iter 25000, accuracy = 0.1491, loss = 0.000848
# Iter 25000, VALIDATION -- accuracy = 0.1729, loss = 0.006072
# PASSAGE
# to date there has been little research into the clinical outcomes of total hip arthroplasty tha for intracapsular neck of femur UNK fracture in the very elderly . 44 patients over UNK underwent tha for an intracapsular UNK fracture over a two year period . oxford hip scores were obtained from 37 patients with a mean score of 39 . 7 range UNK . UNK index scores were collected from 36 patients with a mean preoperative score of 5 . 9 and post operative score of 5 . 7 . tha in this population gives patients the best opportunity to return to premorbid function . when complications occur there is a catastrophic effect on independence . therefore it is important to select these patients appropriately and to optimise their medical condition perioperatively . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD clinical outcomes of total hip arthroplasty for fractured neck of femur in patients over 75 years . PAD PAD
# Ground Truth = clinical outcomes of total hip arthroplasty for fractured neck of femur in patients over 75 years . PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--25000.ckpt
# Iter 25200, accuracy = 0.1363, loss = 0.002488
# Iter 25400, accuracy = 0.1489, loss = 0.003197
# Iter 25600, accuracy = 0.1548, loss = 0.002612
# Iter 25800, accuracy = 0.1511, loss = 0.009778
# Iter 26000, accuracy = 0.1475, loss = 0.000239
# Iter 26000, VALIDATION -- accuracy = 0.1695, loss = 0.007535
# PASSAGE
# the recently solved crystal structure of the UNK cluster UNK UNK is examined using density functional theory dft . the UNK core of the cluster is intrinsically chiral by the arrangement of the au atoms . this is in contrast to the chirality of UNK gold clusters in which the protecting UNK units are arranged in chiral patterns on achiral cores . we interpret the electronic structure of the UNK cluster in terms of the UNK complex model . the UNK cluster cannot be interpreted as a dimer of UNK clusters which are magic . instead a UNK electron configuration of UNK UNK UNK UNK is found . the 2s band is strongly stabilized and the 1d states are nondegenerate with a large gap . ligand protection of the UNK core leads to a significant increase of the UNK and thus stabilization . we also tested a charge of ii which would give rise to an UNK UNK complex . our results indicate that the UNK cluster is indeed more stable . we also investigate the optical properties of the cluster . the experimental absorption spectrum is UNK by timedependent dft . prominent transitions are analyzed by timedependent densityfunctional perturbation
# Model Pred = PAD electronic structure and optical properties of the intrinsically chiral UNK UNK complex UNK . PAD PAD PAD PAD PAD
# Ground Truth = electronic structure and optical properties of the intrinsically chiral UNK UNK complex UNK . PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--26000.ckpt
# Iter 26200, accuracy = 0.1827, loss = 0.002855
# Iter 26400, accuracy = 0.1643, loss = 0.000218
# Iter 26600, accuracy = 0.1676, loss = 0.007563
# Iter 26800, accuracy = 0.1420, loss = 0.002908
# Iter 27000, accuracy = 0.1692, loss = 0.004691
# Iter 27000, VALIDATION -- accuracy = 0.1467, loss = 0.002129
# PASSAGE
# in japan membrane bioreactor mbrs have been installed in 17 smallscale municipal wastewater treatment plants wwtps in the past 8 years together with two recently installed mbrs for largerscale wwtps . in this study design and operating data were collected from 17 of them as part of a followup survey and aspects including system design biological treatment membrane operation problems and costs were UNK . because most of the mbrs were designed according to standardized guidance system configuration of the plants was similar UNK using the modified UNK mle process with membrane units submerged in aerobic tanks following a fine screen and flow equalization tank . this led to effluent quality with biochemical oxygen demand and tn of less than 3 . 5 and 7 . 4 mgl respectively for nine plants on an annual average basis . it was a common practice in extremely UNK plants to operate the membrane systems intermittently . frequency of recovery cleaning events was plantspecific mostly ranging from 1 to 5 UNK . cost evaluation revealed that specific construction costs for the smallscale mbrs were no more than for oxidation ditch plants . although specific energy consumption values tended to be high in the
# Model Pred = PAD design and operating experiences of fullscale municipal membrane bioreactors in japan . PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = design and operating experiences of fullscale municipal membrane bioreactors in japan . PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--27000.ckpt
# Iter 27200, accuracy = 0.1626, loss = 0.005105
# Iter 27400, accuracy = 0.1524, loss = 0.000011
# Iter 27600, accuracy = 0.1823, loss = 0.000016
# Iter 27800, accuracy = 0.1728, loss = 0.002019
# Iter 28000, accuracy = 0.1837, loss = 0.004188
# Iter 28000, VALIDATION -- accuracy = 0.1779, loss = 0.005375
# PASSAGE
# a series of new watersoluble phenyl UNK conjugates containing hydrophilic UNK or UNK UNK moieties were synthesized via a UNK approach . these compounds have a broad spectrum of antitumor activity against a panel of human tumor cell lines . of these derivatives compound UNK effectively suppressed the growth of colon cancer hct116 prostate cancer pc3 and lung cancer h460 xenografts . the growth of hct116 xenografts was almost completely suppressed when cotreated with compound UNK and 5fluorouracil . furthermore compound UNK can induce dna crosslinking and cellcycle arrest at the g2m phase . early preclinical studies including pharmacokinetics in rats inhibition of the herg and 14 days of acute intravenous injection toxicity suggest that compound UNK is a promising candidate for further preclinical studies . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD design and synthesis of potent antitumor watersoluble phenyl UNK conjugates via a UNK approach . PAD PAD PAD PAD
# Ground Truth = design and synthesis of potent antitumor watersoluble phenyl UNK conjugates via a UNK approach . PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--28000.ckpt
# Iter 28200, accuracy = 0.1564, loss = 0.001819
# Iter 28400, accuracy = 0.1377, loss = 0.002342
# Iter 28600, accuracy = 0.1312, loss = 0.000187
# Iter 28800, accuracy = 0.1585, loss = 0.000299
# Iter 29000, accuracy = 0.1463, loss = 0.003452
# Iter 29000, VALIDATION -- accuracy = 0.1842, loss = 0.000213
# PASSAGE
# we aimed to evaluate the combination of the modified response evaluation criteria in solid tumors UNK and contrastenhanced ultrasonography ceus as a tool for the assessment of hepatocellular carcinoma treated with transarterial chemoembolization . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD UNK criteria and contrastenhanced us for the assessment of the response of hepatocellular carcinoma to transarterial chemoembolization . PAD
# Ground Truth = UNK criteria and contrastenhanced us for the assessment of the response of hepatocellular carcinoma to transarterial chemoembolization . PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--29000.ckpt
# Iter 29200, accuracy = 0.1609, loss = 0.000001
# Iter 29400, accuracy = 0.1200, loss = 0.007304
# Iter 29600, accuracy = 0.1610, loss = 0.004545
# Iter 29800, accuracy = 0.1649, loss = 0.002821
# Iter 30000, accuracy = 0.1416, loss = 0.000001
# Iter 30000, VALIDATION -- accuracy = 0.1783, loss = 0.002495
# PASSAGE
# studies of center of mass com motion are fundamental to understanding the dynamics of animal movement and have been carried out extensively for terrestrial and aerial locomotion . but despite a large amount of literature describing different body movement patterns in fishes analyses of how the center of mass moves during UNK propulsion are not available . these data would be valuable for understanding the dynamics of different body movement patterns and the effect of differing body shapes on locomotor force production . in the present study we analyzed the magnitude and frequency components of com motion in three dimensions x surge y sway z UNK in three fish species eel UNK UNK and UNK UNK swimming with four locomotor modes at three speeds using highspeed video and used an image crosscorrelation technique to estimate com motion thus enabling UNK and unrestrained locomotion . UNK swimming by eels shows reduced com surge oscillation magnitude relative to UNK swimming but not compared to UNK using a UNK locomotor style . UNK swimming UNK at 0 . 5 body UNK displays reduced com sway oscillation relative to swimming in a UNK style at higher speeds . oscillation frequency of the com in
# Model Pred = PAD center of mass motion in swimming fish effects of speed and locomotor mode during UNK propulsion . PAD PAD
# Ground Truth = center of mass motion in swimming fish effects of speed and locomotor mode during UNK propulsion . PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--30000.ckpt
# Iter 30200, accuracy = 0.1586, loss = 0.003375
# Iter 30400, accuracy = 0.1711, loss = 0.003805
# Iter 30600, accuracy = 0.1820, loss = 0.000629
# Iter 30800, accuracy = 0.1447, loss = 0.000118
# Iter 31000, accuracy = 0.1377, loss = 0.001822
# Iter 31000, VALIDATION -- accuracy = 0.1486, loss = 0.005095
# PASSAGE
# the aim of this study was to compare survival of patients with uterine sarcomas using the 1988 and 2008 international federation of gynecologists and obstetricians figo staging systems to determine if revised 2008 staging accurately predicts patient survival . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD figo staging for uterine sarcomas can the revised 2008 staging system predict survival outcome better PAD PAD PAD PAD
# Ground Truth = figo staging for uterine sarcomas can the revised 2008 staging system predict survival outcome better PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--31000.ckpt
# Iter 31200, accuracy = 0.1556, loss = 0.001298
# Iter 31400, accuracy = 0.1539, loss = 0.000584
# Iter 31600, accuracy = 0.1540, loss = 0.000007
# Iter 31800, accuracy = 0.1720, loss = 0.003267
# Iter 32000, accuracy = 0.1525, loss = 0.001199
# Iter 32000, VALIDATION -- accuracy = 0.1402, loss = 0.011505
# PASSAGE
# cardiothoracic surgeons and practitioners of cardiovascular medicine have a long history of humanitarian aid . although this is worthwhile at multiple levels and occasionally described in some detail few efforts have a proven algorithm with demonstrable outcomes that suggest effective educational methodology or clinical results approaching accepted standards in developed countries . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD a stepwise model for delivering medical humanitarian aid requiring complex interventions . PAD PAD PAD PAD PAD PAD PAD
# Ground Truth = a stepwise model for delivering medical humanitarian aid requiring complex interventions . PAD PAD PAD PAD PAD PAD PAD PAD
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--32000.ckpt
# Iter 32200, accuracy = 0.1508, loss = 0.000452
# Iter 32400, accuracy = 0.1453, loss = 0.004183
# Iter 32600, accuracy = 0.1681, loss = 0.000001
# Iter 32800, accuracy = 0.1671, loss = 0.000313
# Iter 33000, accuracy = 0.1639, loss = 0.000005
# Iter 33000, VALIDATION -- accuracy = 0.1516, loss = 0.003709
# PASSAGE
# dynamic mathematical modelling and stochastic simulation of UNK systems for the purpose of epidemiological analysis offer great opportunities for testing hypotheses especially when field experiments are impractical or when there is a need to evaluate multiple experimental scenarios . this combined with the ever increasing computer power available to researchers has contributed to the development of many mathematical models for epidemic simulations such as the individualbased model ibm . nevertheless few of these models undergo extensive validation and proper assessment of intrinsic variability . the ontario rabies model UNK will be used here to exemplify some advantages of appropriate model behaviour validation and to illustrate the use of a simple geometric procedure for testing directional bias in distributed stochastic dynamic model of spread of diseases . results were obtained through the comparison of 10 000 epizootics resulting from 100 epidemic simulations started using 100 distinct base populations . the analysis results demonstrated a significant directional bias in epidemic dispersion which prompted further verification of the model code and the identification of a coding error which was then corrected . subsequent testing of the corrected code showed that the directional bias could no longer be detected . these results illustrate the
# Model Pred = PAD a simple geometric validation approach to assess the basic behaviour of space and time distributed models of epidemic spread
# Ground Truth = a simple geometric validation approach to assess the basic behaviour of space and time distributed models of epidemic spread an
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--33000.ckpt
# Iter 33200, accuracy = 0.1715, loss = 0.000003
# Iter 33400, accuracy = 0.1916, loss = 0.000169
# Iter 33600, accuracy = 0.1668, loss = 0.001909
# Iter 33800, accuracy = 0.1378, loss = 0.000001
# Iter 34000, accuracy = 0.1595, loss = 0.007386
# Iter 34000, VALIDATION -- accuracy = 0.1606, loss = 0.008615
# PASSAGE
# there is a strong need to define the molecular changes in normal atrisk breast epithelium to identify biomarkers and new targets for breast cancer prevention and to develop a molecular signature for risk assessment . improved methods of breast epithelial sampling are needed to promote wholegenome molecular profiling increase ductal epithelial cell yield and reduce sample cell heterogeneity . PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD PAD
# Model Pred = PAD an improved breast epithelial sampling method for molecular profiling and biomarker analysis in women at risk for breast cancer
# Ground Truth = an improved breast epithelial sampling method for molecular profiling and biomarker analysis in women at risk for breast cancer .
#
# Model saved in file: /home/ai2-rey/Documents/code/Nikhita/Text  Summarization /weights/seq2seq_weights_iter--34000.ckpt
# Iter 34200, accuracy = 0.1899, loss = 0.003785
# Iter 34400, accuracy = 0.1937, loss = 0.000349
# Iter 34600, accuracy = 0.1643, loss = 0.000012
# Iter 34800, accuracy = 0.1730, loss = 0.002702
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-b5c49ab21ea3> in <module>()
#      21                        batch_size: train_data_iter.batch_size}
#      22
# ---> 23     sess.run(optimizer, feed_dict=train_feed_dict)
#      24
#      25     if train_iter % display_step ==0:
#
# /home/ai2-rey/anaconda3/envs/tensorflow_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ai2-rey/anaconda3/envs/tensorflow_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /home/ai2-rey/anaconda3/envs/tensorflow_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ai2-rey/anaconda3/envs/tensorflow_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /home/ai2-rey/anaconda3/envs/tensorflow_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
